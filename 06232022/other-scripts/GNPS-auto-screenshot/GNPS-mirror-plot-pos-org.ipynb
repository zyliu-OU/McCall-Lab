# %%
import sys
# !{sys.executable} -m pip install selenium==4.16

# %%
import sys
# !{sys.executable} -m pip install webdriver-manager==3.8.5
# Out:
# Requirement already satisfied: webdriver-manager==3.8.5 in c:\users\cos-chem-mccall\appdata\local\anaconda3\lib\site-packages (3.8.5)
# Requirement already satisfied: requests in c:\users\cos-chem-mccall\appdata\local\anaconda3\lib\site-packages (from webdriver-manager==3.8.5) (2.31.0)
# Requirement already satisfied: python-dotenv in c:\users\cos-chem-mccall\appdata\local\anaconda3\lib\site-packages (from webdriver-manager==3.8.5) (0.21.0)
# Requirement already satisfied: tqdm in c:\users\cos-chem-mccall\appdata\local\anaconda3\lib\site-packages (from webdriver-manager==3.8.5) (4.65.0)
# Requirement already satisfied: packaging in c:\users\cos-chem-mccall\appdata\local\anaconda3\lib\site-packages (from webdriver-manager==3.8.5) (23.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\cos-chem-mccall\appdata\local\anaconda3\lib\site-packages (from requests->webdriver-manager==3.8.5) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\cos-chem-mccall\appdata\local\anaconda3\lib\site-packages (from requests->webdriver-manager==3.8.5) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\cos-chem-mccall\appdata\local\anaconda3\lib\site-packages (from requests->webdriver-manager==3.8.5) (1.26.19)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\cos-chem-mccall\appdata\local\anaconda3\lib\site-packages (from requests->webdriver-manager==3.8.5) (2024.6.2)
# Requirement already satisfied: colorama in c:\users\cos-chem-mccall\appdata\local\anaconda3\lib\site-packages (from tqdm->webdriver-manager==3.8.5) (0.4.6)

# %%
import sys
# !{sys.executable} -m pip install chromedriver-binary==128.0.6613.84.0

# %%
#make sure there are no duplicates in your cluster_index data column

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.common.exceptions import NoSuchElementException
import chromedriver_binary
import pandas as pd
import time

# change the file name to yours, make sure the cluster index column name is "cluster_index"
data_feature = pd.read_csv("Metabolomics_SI_table_org.csv")
feature_list = data_feature.cluster_index_fix.to_list()
print(feature_list)
driver = webdriver.Chrome()
# change GNPS link to yours
driver.get("https://gnps.ucsd.edu/ProteoSAFe/status.jsp?task=2375d668a98241b3b6b652cef71b2452")
driver.maximize_window()

# change time if there are some error, which might 
# because loading time is too long and need more time until the picture show up
time_to_wait = 30

# check all library hits
all_library_hits_button = driver.find_element(By.XPATH, '/html/body/div/div[2]/table/tbody/tr[2]/td/table/tbody/tr[2]/td/div[4]/a[1]')
all_library_hits_button.click()
WebDriverWait(driver, time_to_wait).until(lambda s: s.find_element(By.ID, 'main.#Scan#_lowerinput').is_displayed()) 

for cluster_index in feature_list:
    cluster_index_lower = driver.find_element(By.ID, 'main.#Scan#_lowerinput')
    cluster_index_upper = driver.find_element(By.ID, 'main.#Scan#_upperinput')
    cluster_index_lower.send_keys(str(cluster_index))
    cluster_index_upper.send_keys(str(cluster_index))
    cluster_index_upper.send_keys(Keys.ENTER)
    try:
        view_mirror_buttom = driver.find_element(By.XPATH, '/html/body/div[3]/div[1]/table/tbody/tr[1]/td[1]/button[1]')
        WebDriverWait(driver, time_to_wait).until(lambda s: s.find_element(By.XPATH, '/html/body/div[3]/div[1]/table/tbody/tr[1]/td[1]/button[1]').is_displayed()) 
        view_mirror_buttom.click()
        WebDriverWait(driver, time_to_wait).until(lambda s: s.find_element(By.XPATH, '/html/body/div[3]/div[1]/table/tbody/tr[3]/td[2]/div/div/table/tbody/tr[3]/td/div[1]/canvas[2]').is_displayed())        
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        driver.find_element(By.XPATH,'/html/body/div[3]/div[1]/table/tbody/tr[3]/td[2]/div/div/table/tbody/tr[3]').screenshot('all-library-hit-' + str(cluster_index) + '.png')
        print("mirror plot exist " + str(cluster_index))
        cluster_index_lower.clear()
        cluster_index_upper.clear()
    except NoSuchElementException:
        print('mirror plot not exist ' + str(cluster_index))
        cluster_index_lower.clear()
        cluster_index_upper.clear()

back_status_page_button = driver.find_element(By.XPATH, '/html/body/div[1]/div/table/tbody/tr[1]/td[2]/a')
back_status_page_button.click()

# check analog library hits
analog_library_hits_button = driver.find_element(By.XPATH, '/html/body/div/div[2]/table/tbody/tr[2]/td/table/tbody/tr[2]/td/div[4]/a[3]')
analog_library_hits_button.click()
WebDriverWait(driver, time_to_wait).until(lambda s: s.find_element(By.ID, 'main.#Scan#_lowerinput').is_displayed()) 

for cluster_index in feature_list:
    cluster_index_lower = driver.find_element(By.ID, 'main.#Scan#_lowerinput')
    cluster_index_upper = driver.find_element(By.ID, 'main.#Scan#_upperinput')
    cluster_index_lower.send_keys(str(cluster_index))
    cluster_index_upper.send_keys(str(cluster_index))
    cluster_index_upper.send_keys(Keys.ENTER)
    try:
        view_mirror_buttom = driver.find_element(By.XPATH, '/html/body/div[3]/div[1]/table/tbody/tr[1]/td[1]/img')
        WebDriverWait(driver, time_to_wait).until(lambda s: s.find_element(By.XPATH, '/html/body/div[3]/div[1]/table/tbody/tr[1]/td[1]/img').is_displayed()) 
        view_mirror_buttom.click()
        # some analog mirror plots take time to load
        time.sleep(time_to_wait)
        WebDriverWait(driver, time_to_wait).until(lambda s: s.find_element(By.XPATH, '/html/body/div[3]/div[1]/table/tbody/tr[2]/td[2]/div/div/table/tbody/tr[3]').is_displayed())        
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        driver.find_element(By.XPATH,'/html/body/div[3]/div[1]/table/tbody/tr[2]/td[2]/div/div/table/tbody/tr[3]').screenshot('analog-library-hit-' + str(cluster_index) + '.png')
        print("analog mirror plot exist " + str(cluster_index))
        cluster_index_lower.clear()
        cluster_index_upper.clear()
    except NoSuchElementException:
        print('analog mirror plot not exist ' + str(cluster_index))
        cluster_index_lower.clear()
        cluster_index_upper.clear()

# close the browser after it finished
WebDriverWait(driver, time_to_wait)
driver.close()
# Out:
# [587, 596, 1188, 2466, 55, 3632, 1543, 1316, 1693, 1874, 243, 3193, 562, 1104, 307, 563, 1178, 1617, 48, 571, 1162, 1595, 322, 1456, 1258, 3463, 576, 1592, 606, 634, 1481, 2467, 2353, 3557, 2143, 1854, 1166, 3586, 3467, 1227, 1390, 1212, 1286, 1234, 127, 1290, 13, 1451, 43, 1459, 1497, 113, 1602, 1616, 1768, 1731, 707, 1793, 1798, 3740, 851, 647, 1202, 2514, 1465, 614, 2608, 1674, 2915, 3891, 2710, 1491, 3245, 1788, 3847, 1492, 522, 2606, 3559, 3175, 1236, 2585, 3504, 639, 7, 1527, 929, 936, 2051, 3126, 1224, 3752, 3848]
# mirror plot exist 587
# mirror plot exist 596
# mirror plot exist 1188
# mirror plot exist 2466
# mirror plot exist 55
# mirror plot exist 3632
# mirror plot exist 1543
# mirror plot exist 1316
# mirror plot exist 1693
# mirror plot exist 1874
# mirror plot exist 243
# mirror plot exist 3193
# mirror plot exist 562
# mirror plot exist 1104
# mirror plot exist 307
# mirror plot exist 563
# mirror plot exist 1178
# mirror plot exist 1617
# mirror plot exist 48
# mirror plot exist 571
# mirror plot exist 1162
# mirror plot exist 1595
# mirror plot exist 322
# mirror plot exist 1456
# mirror plot exist 1258
# mirror plot exist 3463
# mirror plot exist 576
# mirror plot exist 1592
# mirror plot exist 606
# mirror plot exist 634
# mirror plot exist 1481
# mirror plot exist 2467
# mirror plot exist 2353
# mirror plot exist 3557
# mirror plot exist 2143
# mirror plot exist 1854
# mirror plot exist 1166
# mirror plot exist 3586
# mirror plot exist 3467
# mirror plot not exist 1227
# mirror plot not exist 1390
# mirror plot not exist 1212
# mirror plot not exist 1286
# mirror plot not exist 1234
# mirror plot not exist 127
# mirror plot not exist 1290
# mirror plot not exist 13
# mirror plot not exist 1451
# mirror plot not exist 43
# mirror plot not exist 1459
# mirror plot not exist 1497
# mirror plot not exist 113
# mirror plot not exist 1602
# mirror plot not exist 1616
# mirror plot not exist 1768
# mirror plot not exist 1731
# mirror plot not exist 707
# mirror plot not exist 1793
# mirror plot not exist 1798
# mirror plot not exist 3740
# mirror plot not exist 851
# mirror plot not exist 647
# mirror plot not exist 1202
# mirror plot not exist 2514
# mirror plot not exist 1465
# mirror plot not exist 614
# mirror plot not exist 2608
# mirror plot not exist 1674
# mirror plot not exist 2915
# mirror plot not exist 3891
# mirror plot not exist 2710
# mirror plot not exist 1491
# mirror plot not exist 3245
# mirror plot not exist 1788
# mirror plot not exist 3847
# mirror plot not exist 1492
# mirror plot not exist 522
# mirror plot not exist 2606
# mirror plot not exist 3559
# mirror plot not exist 3175
# mirror plot not exist 1236
# mirror plot not exist 2585
# mirror plot exist 3504
# mirror plot not exist 639
# mirror plot not exist 7
# mirror plot not exist 1527
# mirror plot not exist 929
# mirror plot not exist 936
# mirror plot exist 2051
# mirror plot exist 3126
# mirror plot not exist 1224
# mirror plot not exist 3752
# mirror plot not exist 3848
# analog mirror plot exist 587
# analog mirror plot exist 596
# analog mirror plot exist 1188
# analog mirror plot exist 2466
# analog mirror plot exist 55
# analog mirror plot exist 3632
# analog mirror plot exist 1543
# analog mirror plot exist 1316
# analog mirror plot exist 1693
# analog mirror plot exist 1874
# analog mirror plot exist 243
# analog mirror plot exist 3193
# analog mirror plot exist 562
# analog mirror plot exist 1104
# analog mirror plot exist 307
# analog mirror plot exist 563
# analog mirror plot exist 1178
# analog mirror plot exist 1617
# analog mirror plot exist 48
# analog mirror plot exist 571
# analog mirror plot exist 1162
# analog mirror plot exist 1595
# analog mirror plot exist 322
# analog mirror plot exist 1456
# analog mirror plot exist 1258
# analog mirror plot exist 3463
# analog mirror plot exist 576
# analog mirror plot exist 1592
# analog mirror plot exist 606
# analog mirror plot exist 634
# analog mirror plot exist 1481
# analog mirror plot exist 2467
# analog mirror plot exist 2353
# analog mirror plot exist 3557
# analog mirror plot exist 2143
# analog mirror plot exist 1854
# analog mirror plot exist 1166
# analog mirror plot exist 3586
# analog mirror plot exist 3467
# ---------------------------------------------------------------------------
# TimeoutException                          Traceback (most recent call last)
# Cell In[2], line 69
#      67 # some analog mirror plots take time to load
#      68 time.sleep(time_to_wait)
# ---> 69 WebDriverWait(driver, time_to_wait).until(lambda s: s.find_element(By.XPATH, '/html/body/div[3]/div[1]/table/tbody/tr[2]/td[2]/div/div/table/tbody/tr[3]').is_displayed())
#      70 driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
#      71 driver.find_element(By.XPATH,'/html/body/div[3]/div[1]/table/tbody/tr[2]/td[2]/div/div/table/tbody/tr[3]').screenshot('analog-library-hit-' + str(cluster_index) + '.png')
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\selenium\webdriver\support\wait.py:105, in WebDriverWait.until(self, method, message)
#     103     if time.monotonic() > end_time:
#     104         break
# --> 105 raise TimeoutException(message, screen, stacktrace)
#
# TimeoutException: Message:
# Stacktrace:
# 	GetHandleVerifier [0x00007FF7504CB632+29090]
# 	(No symbol) [0x00007FF75043E6E9]
# 	(No symbol) [0x00007FF7502FB1CA]
# 	(No symbol) [0x00007FF75034EFD7]
# 	(No symbol) [0x00007FF75034F22C]
# 	(No symbol) [0x00007FF7503997F7]
# 	(No symbol) [0x00007FF75037672F]
# 	(No symbol) [0x00007FF7503965D9]
# 	(No symbol) [0x00007FF750376493]
# 	(No symbol) [0x00007FF7503409B1]
# 	(No symbol) [0x00007FF750341B11]
# 	GetHandleVerifier [0x00007FF7507E881D+3294093]
# 	GetHandleVerifier [0x00007FF750834403+3604339]
# 	GetHandleVerifier [0x00007FF75082A2C7+3563063]
# 	GetHandleVerifier [0x00007FF750586F16+797318]
# 	(No symbol) [0x00007FF75044986F]
# 	(No symbol) [0x00007FF750445454]
# 	(No symbol) [0x00007FF7504455E0]
# 	(No symbol) [0x00007FF750434A7F]
# 	BaseThreadInitThunk [0x00007FFB96CE7374+20]
# 	RtlUserThreadStart [0x00007FFB98CDCC91+33]
