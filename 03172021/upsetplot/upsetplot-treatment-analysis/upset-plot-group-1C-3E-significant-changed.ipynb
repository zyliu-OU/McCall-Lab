# %%
# the main reason to have this upset plot is that 
# we want to see the overlap of features impacted by infection between 6 heart sections.


import pandas
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns; sns.set_theme(color_codes=True)
from matplotlib.pyplot import gcf
from upsetplot import UpSet
from matplotlib import cm

# import superclass information from molnetenhancer data.
# features in rows.
data_b = pandas.read_csv("treatment-9-15-RF-2dot1-annotation-final-fix-split-mass.csv")
data_b = data_b.set_index(['filename'])
mass_class_series = data_b.pop("classes")

data_LA = pandas.read_csv("union-9-15-LA-fix.csv")
data_LA = data_LA.set_index(['filename'])

data_RA = pandas.read_csv("union-9-15-RA-fix.csv")
data_RA = data_RA.set_index(['filename'])

data_LVT = pandas.read_csv("union-9-15-LVT-fix.csv")
data_LVT = data_LVT.set_index(['filename'])

data_LVB = pandas.read_csv("union-9-15-LVB-fix.csv")
data_LVB = data_LVB.set_index(['filename'])

data_RVT = pandas.read_csv("union-9-15-RVT-fix.csv")
data_RVT = data_RVT.set_index(['filename'])

data_RVB = pandas.read_csv("union-9-15-RVB-fix.csv")
data_RVB = data_RVB.set_index(['filename'])

# upset plot seems can not use string, only can use number, so transfer letter to number
trans_number = {'group9_group15':1, 'group9':1, 'group15':1,'not_restored':1}

recover_series_LA = data_LA.pop("LA")
col_colors_LA = recover_series_LA.map(trans_number)

recover_series_RA = data_RA.pop("RA")
col_colors_RA = recover_series_RA.map(trans_number)

recover_series_LVT = data_LVT.pop("LVT")
col_colors_LVT = recover_series_LVT.map(trans_number)

recover_series_LVB = data_LVB.pop("LVB")
col_colors_LVB = recover_series_LVB.map(trans_number)

recover_series_RVT = data_RVT.pop("RVT")
col_colors_RVT = recover_series_RVT.map(trans_number)

recover_series_RVB = data_RVB.pop("RVB")
col_colors_RVB = recover_series_RVB.map(trans_number)

col_colors = pandas.DataFrame(col_colors_LA).join(pandas.DataFrame(col_colors_RA),how='outer').join(pandas.DataFrame(col_colors_LVT),how='outer').join(pandas.DataFrame(col_colors_LVB),how='outer').join(pandas.DataFrame(col_colors_RVT),how='outer').join(pandas.DataFrame(col_colors_RVB),how='outer').join(pandas.DataFrame(mass_class_series), how = 'inner')

col_colors = col_colors.set_index(col_colors.LA == 1).set_index(col_colors.RA == 1, append=True).set_index(col_colors.LVT == 1, append=True).set_index(col_colors.LVB == 1, append=True).set_index(col_colors.RVT == 1, append=True).set_index(col_colors.RVB == 1, append=True)

metabolites_color = {'No matches':(0.12156862745098039, 0.4666666666666667, 0.7058823529411765),
           'Benzenoids':(1.0, 0.4980392156862745, 0.054901960784313725), 
           'Organic acids and derivatives':(0.17254901960784313, 0.6274509803921569, 0.17254901960784313), 
           'Lipids and lipid-like molecules':(0.8392156862745098, 0.15294117647058825, 0.1568627450980392), 
           'Organoheterocyclic compounds':(0.5803921568627451, 0.403921568627451, 0.7411764705882353),
           'Nucleosides, nucleotides, and analogues':(0.5490196078431373, 0.33725490196078434, 0.29411764705882354),
           'Phenylpropanoids and polyketides':(0.8901960784313725, 0.4666666666666667, 0.7607843137254902), 
           'Organic nitrogen compounds':(0.4980392156862745, 0.4980392156862745, 0.4980392156862745),
           'Organic oxygen compounds':(0.7372549019607844, 0.7411764705882353, 0.13333333333333333)}

# plot the upset plot
upset = UpSet(col_colors,show_counts = True, intersection_plot_elements=0, sort_categories_by = None, element_size=20)  # disable the default bar chart
upset.add_stacked_bars(by='classes', colors=metabolites_color, title="Count by classes", elements=10)
plt.figure(figsize = (40, 20))
plt.style.use('default')
upset.plot()
plt.legend(bbox_to_anchor=(1.01,1))
plt.suptitle("Metabolites impacted by infection")
plt.savefig("upset-plot-infection-impacted.pdf", dpi = 300, bbox_inches = 'tight')
plt.savefig("upset-plot-infection-impacted.png", dpi = 300, bbox_inches = 'tight')

# %%
print(recover_series_LA)
print(recover_series_RA)
print(recover_series_LVT)
print(recover_series_LVB)
print(recover_series_RVT)
print(recover_series_RVB)
# Out:
# filename
# X385.165_2.771    group9_group15
# X114.092_1.761    group9_group15
# X102.092_0.611    group9_group15
# X430.223_2.769    group9_group15
# X280.263_3.169    group9_group15
# X387.192_2.843    group9_group15
# X679.068_2.179    group9_group15
# X377.146_2.225            group9
# X258.111_0.302           group15
# X616.308_2.766           group15
# X608.393_3.098           group15
# X604.442_3.001      not_restored
# X664.463_2.992      not_restored
# X620.437_2.993      not_restored
# X708.489_2.982      not_restored
# X516.39_3.018       not_restored
# X488.359_3.01       not_restored
# X560.416_3.006      not_restored
# X137.046_0.35       not_restored
# X648.468_2.995      not_restored
# X532.385_3.004      not_restored
# X576.411_2.999      not_restored
# X666.433_3.092      not_restored
# X752.515_2.977      not_restored
# X472.363_3.023      not_restored
# X650.403_3.014      not_restored
# X898.581_3.224      not_restored
# X428.205_2.248      not_restored
# X444.332_3.016      not_restored
# X166.053_0.305      not_restored
# X368.389_3.90     group9_group15
# Name: LA, dtype: object
# filename
# X111.044_2.768    group9_group15
# X249.112_2.768    group9_group15
# X263.2_2.895      group9_group15
# X296.258_2.976    group9_group15
# X141.959_6.859    group9_group15
# X369.17_2.767     group9_group15
# X285.133_2.768    group9_group15
# X650.978_2.339    group9_group15
# X105.07_2.767     group9_group15
# X276.02_2.431     group9_group15
# X281.102_2.768    group9_group15
# X409.162_2.768    group9_group15
# X425.136_2.773    group9_group15
# X489.228_2.768    group9_group15
# X538.315_2.977    group9_group15
# X263.091_2.771    group9_group15
# X748.439_2.944    group9_group15
# X664.419_3.086    group9_group15
# X596.357_2.948    group9_group15
# X142.027_0.328    group9_group15
# X448.342_2.867    group9_group15
# X696.443_3.1      group9_group15
# X305.248_3.26     group9_group15
# X192.125_4.643    group9_group15
# X668.414_2.975    group9_group15
# X295.227_3.017    group9_group15
# X400.342_2.89            group15
# X696.445_3.083           group15
# X137.046_0.35            group15
# X440.337_2.765    group9_group15
# Name: RA, dtype: object
# filename
# X249.112_2.768            group9
# X608.227_2.768    group9_group15
# X720.445_3.09             group9
# X737.391_2.399            group9
# X690.434_3.14             group9
# X776.042_2.398    group9_group15
# X776.095_2.398            group9
# X776.148_2.398            group9
# X776.359_2.398            group9
# X819.433_2.399            group9
# X296.258_2.976    group9_group15
# X692.414_2.985            group9
# X708.445_3.006    group9_group15
# X867.281_2.399            group9
# X546.029_2.319            group9
# X141.091_1.54     group9_group15
# X607.227_2.771            group9
# X709.936_2.18     group9_group15
# X366.373_3.699    group9_group15
# X345.243_3.095            group9
# X272.222_2.957            group9
# X311.221_2.932           group15
# X203.007_0.309           group15
# X240.116_2.324      not_restored
# X293.211_2.933           group15
# X442.353_2.823      not_restored
# X440.337_2.765           group15
# Name: LVT, dtype: object
# filename
# X440.359_2.985            group9
# X792.329_2.764    group9_group15
# X484.385_2.982            group9
# X396.332_2.991            group9
# X352.306_2.997            group9
# X387.193_2.842    group9_group15
# X249.112_2.768            group9
# X599.241_2.765            group9
# X811.309_2.773    group9_group15
# X489.228_2.768            group9
# X258.207_2.775            group9
# X430.223_2.769            group9
# X764.524_3.729    group9_group15
# X369.17_2.767             group9
# X790.38_2.768             group9
# X795.335_2.768            group9
# X267.123_2.767            group9
# X604.362_2.948            group9
# X105.07_2.767             group9
# X291.146_2.39            group15
# X119.049_2.765           group15
# X620.356_2.913           group15
# X494.325_2.865           group15
# X386.717_2.856           group15
# X251.037_0.323           group15
# X128.018_0.344      not_restored
# X380.993_2.164      not_restored
# X416.337_2.79       not_restored
# X682.364_3.313      not_restored
# X475.989_2.164      not_restored
# X458.23_2.165       not_restored
# X682.363_3.329      not_restored
# X137.046_0.35       not_restored
# X136.062_0.301      not_restored
# X324.327_3.455      not_restored
# X296.258_2.976      not_restored
# X476.24_2.164       not_restored
# X420.899_2.103      not_restored
# X580.361_2.989      not_restored
# X136.097_0.551      not_restored
# X397.22_2.071       not_restored
# X301.115_0.413      not_restored
# X580.362_2.984      not_restored
# X466.25_2.226       not_restored
# X351.217_2.741      not_restored
# X570.357_2.934      not_restored
# X301.115_0.328      not_restored
# X203.007_0.309      not_restored
# X256.264_3.225      not_restored
# X400.97_2.127       not_restored
# X426.484_2.164      not_restored
# X285.133_2.768      not_restored
# X137.046_0.42       not_restored
# X440.337_2.765      not_restored
# X442.353_2.823      not_restored
# Name: LVB, dtype: object
# filename
# X792.329_2.764    group9_group15
# X489.228_2.768    group9_group15
# X111.044_2.768    group9_group15
# X216.16_2.471     group9_group15
# X333.063_2.524    group9_group15
#                        ...
# X666.434_3.024      not_restored
# X776.253_2.398      not_restored
# X256.227_3.318      not_restored
# X268.105_0.35       not_restored
# X269.088_0.35       not_restored
# Name: RVT, Length: 63, dtype: object
# filename
# X348.288_3.044    group9_group15
# X278.186_2.23     group9_group15
# X300.199_2.264            group9
# X256.227_2.847    group9_group15
# X214.181_2.634            group9
#                        ...
# X446.218_2.884      not_restored
# X475.989_2.164      not_restored
# X200.165_3.207      not_restored
# X268.105_0.35       not_restored
# X269.088_0.35       not_restored
# Name: RVB, Length: 64, dtype: object
