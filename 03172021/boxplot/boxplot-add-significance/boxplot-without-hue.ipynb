# %%
import pandas
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from statannotations.Annotator import Annotator

data_a = pandas.read_csv('03172021-PC-M-F-treatment-sum-peak.csv')

data_LA = data_a[data_a["organ"].isin(["LA"])]
data_RA = data_a[data_a["organ"].isin(["RA"])]
data_LVT = data_a[data_a["organ"].isin(["LV_top"])]
data_LVB = data_a[data_a["organ"].isin(["LV_bottom"])]
data_RVT = data_a[data_a["organ"].isin(["RV_top"])]
data_RVB = data_a[data_a["organ"].isin(["RV_bottom"])]

mass_list = ['mass_400', 'mass_500', 'mass_600', 'mass_700', 'mass_800']
print(mass_list)

# change the theme of the plot
sns.set_theme(style="white")

plt.rc('xtick',labelsize=16)
plt.rc('ytick',labelsize=16)

order = ["naive", 'infected', 'combo', 'BNZ']

mass_list_number = 1
for mass in mass_list:
    fig, axes = plt.subplots(2, 3, figsize=(27, 15), constrained_layout=True)
    fig.suptitle(mass)
    g1 = sns.boxplot(ax=axes[0, 0], x=data_LA[str(mass)], y=data_LA['Treatmentgroup'], order = order, palette="tab10", showfliers = False)
    g1 = sns.stripplot(ax=axes[0, 0], x=data_LA[str(mass)], y=data_LA['Treatmentgroup'], order = order, dodge=True, color = "black", size=2, edgecolor="black", linewidth=.9)
    axes[0, 0].set_title("LA", fontsize=16)
    axes[0, 0].set_xlabel('Normalized peak area', fontsize=16)
    #axes[0, 0].set_ylabel('', fontsize=16)
    
    annot_1 = Annotator(g1, [("naive", "infected"), ("naive", "combo"), ("naive", "BNZ"), ("infected", "combo"), ("infected", "BNZ"), ("combo", "BNZ")], y=data_LA['Treatmentgroup'], x=data_LA[str(mass)], order=order, orient='h')
    annot_1.configure(test='Mann-Whitney', comparisons_correction="BH", correction_format="replace", text_format='star', loc='outside', verbose=2)
    annot_1.apply_test()
    plot_1, test_results = annot_1.annotate()

    g2 = sns.boxplot(ax=axes[0, 1], x=data_RA[str(mass)], y=data_RA['Treatmentgroup'], order = ["naive", 'infected', 'combo', 'BNZ'], palette="tab10", showfliers = False)
    g2 = sns.stripplot(ax=axes[0, 1], x=data_RA[str(mass)], y=data_RA['Treatmentgroup'], order = ["naive", 'infected', 'combo', 'BNZ'], dodge=True, color = "black", size=2, edgecolor="black", linewidth=.9)
    axes[0, 1].set_title("RA", fontsize=16)
    axes[0, 1].set_xlabel('Normalized peak area', fontsize=16)
    #axes[0, 1].set_ylabel('', fontsize=16)
    
    annot_2 = Annotator(g2, [("naive", "infected"), ("naive", "combo"), ("naive", "BNZ"), ("infected", "combo"), ("infected", "BNZ"), ("combo", "BNZ")], y=data_RA['Treatmentgroup'], x=data_RA[str(mass)], order=order, orient='h')
    annot_2.configure(test='Mann-Whitney', comparisons_correction="BH", correction_format="replace", text_format='star', loc='outside', verbose=2)
    annot_2.apply_test()
    plot_2, test_results = annot_2.annotate()

    g3 = sns.boxplot(ax=axes[0, 2], x=data_LVT[str(mass)], y=data_LVT['Treatmentgroup'], order = ["naive", 'infected', 'combo', 'BNZ'], palette="tab10", showfliers = False)
    g3 = sns.stripplot(ax=axes[0, 2], x=data_LVT[str(mass)], y=data_LVT['Treatmentgroup'], order = ["naive", 'infected', 'combo', 'BNZ'], dodge=True, color = "black", size=2, edgecolor="black", linewidth=.9)
    axes[0, 2].set_title("LVT", fontsize=16)
    axes[0, 2].set_xlabel('Normalized peak area', fontsize=16)
    #axes[0, 2].set_ylabel('', fontsize=16)
    
    annot_3 = Annotator(g3, [("naive", "infected"), ("naive", "combo"), ("naive", "BNZ"), ("infected", "combo"), ("infected", "BNZ"), ("combo", "BNZ")], y=data_LVT['Treatmentgroup'], x=data_LVT[str(mass)], order=order, orient='h')
    annot_3.configure(test='Mann-Whitney', comparisons_correction="BH", correction_format="replace", text_format='star', loc='outside', verbose=2)
    annot_3.apply_test()
    plot_3, test_results = annot_3.annotate()
    
    g4 = sns.boxplot(ax=axes[1, 0], x=data_LVB[str(mass)], y=data_LVB['Treatmentgroup'], order = ["naive", 'infected', 'combo', 'BNZ'], palette="tab10", showfliers = False)
    g4 = sns.stripplot(ax=axes[1, 0], x=data_LVB[str(mass)], y=data_LVB['Treatmentgroup'], order = ["naive", 'infected', 'combo', 'BNZ'], dodge=True, color = "black", size=2, edgecolor="black", linewidth=.9)
    axes[1, 0].set_title("LVB", fontsize=16)
    axes[1, 0].set_xlabel('Normalized peak area', fontsize=16)
    #axes[1, 0].set_ylabel('', fontsize=16)
    
    annot_4 = Annotator(g4, [("naive", "infected"), ("naive", "combo"), ("naive", "BNZ"), ("infected", "combo"), ("infected", "BNZ"), ("combo", "BNZ")], y=data_LVB['Treatmentgroup'], x=data_LVB[str(mass)], order=order, orient='h')
    annot_4.configure(test='Mann-Whitney', comparisons_correction="BH", correction_format="replace", text_format='star', loc='outside', verbose=2)
    annot_4.apply_test()
    plot_4, test_results = annot_4.annotate()
    
    g5 = sns.boxplot(ax=axes[1, 1], x=data_RVT[str(mass)], y=data_RVT['Treatmentgroup'], order = ["naive", 'infected', 'combo', 'BNZ'], palette="tab10", showfliers = False)
    g5 = sns.stripplot(ax=axes[1, 1], x=data_RVT[str(mass)], y=data_RVT['Treatmentgroup'], order = ["naive", 'infected', 'combo', 'BNZ'], dodge=True, color = "black", size=2, edgecolor="black", linewidth=.9)
    axes[1, 1].set_title("RVT", fontsize=16)
    axes[1, 1].set_xlabel('Normalized peak area', fontsize=16)
    #axes[1, 1].set_ylabel('', fontsize=16)
    
    annot_5 = Annotator(g5, [("naive", "infected"), ("naive", "combo"), ("naive", "BNZ"), ("infected", "combo"), ("infected", "BNZ"), ("combo", "BNZ")], y=data_RVT['Treatmentgroup'], x=data_RVT[str(mass)], order=order, orient='h')
    annot_5.configure(test='Mann-Whitney', comparisons_correction="BH", correction_format="replace", text_format='star', loc='outside', verbose=2)
    annot_5.apply_test()
    plot_5, test_results = annot_5.annotate()
    
    g6 = sns.boxplot(ax=axes[1, 2], x=data_RVB[str(mass)], y=data_RVB['Treatmentgroup'], order = ["naive", 'infected', 'combo', 'BNZ'], palette="tab10", showfliers = False)
    g6 = sns.stripplot(ax=axes[1, 2], x=data_RVB[str(mass)], y=data_RVB['Treatmentgroup'], order = ["naive", 'infected', 'combo', 'BNZ'], dodge=True, color = "black", size=2, edgecolor="black", linewidth=.9)
    axes[1, 2].set_title("RVB", fontsize=16)
    axes[1, 2].set_xlabel('Normalized peak area', fontsize=16)
    #axes[1, 2].set_ylabel('', fontsize=16)
    
    annot_6 = Annotator(g6, [("naive", "infected"), ("naive", "combo"), ("naive", "BNZ"), ("infected", "combo"), ("infected", "BNZ"), ("combo", "BNZ")], y=data_RVB['Treatmentgroup'], x=data_RVB[str(mass)], order=order, orient='h')
    annot_6.configure(test='Mann-Whitney', comparisons_correction="BH", correction_format="replace", text_format='star', loc='outside', verbose=2)
    annot_6.apply_test()
    plot_6, test_results = annot_6.annotate()
    
    #sns.move_legend(g1, "upper right")
    #sns.move_legend(g2, "upper right")
    #sns.move_legend(g3, "upper right")
    #sns.move_legend(g4, "upper right")
    #sns.move_legend(g5, "upper right")
    #sns.move_legend(g6, "upper right")
    g1.legend([],[], frameon=False)
    g2.legend([],[], frameon=False)
    g3.legend([],[], frameon=False)
    g4.legend([],[], frameon=False)
    g5.legend([],[], frameon=False)
    g6.legend([],[], frameon=False)
    plt.savefig("6-HS-boxplot-treatment-sum-peaks-" + str(mass) + ".png", dpi=300, bbox_inches='tight')
    mass_list_number += 1
# Out:
# ['mass_400', 'mass_500', 'mass_600', 'mass_700', 'mass_800']
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# naive vs. infected: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:4.553e-01 U_stat=9.400e+01
# infected vs. combo: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:4.553e-01 U_stat=1.310e+02
# combo vs. BNZ: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:1.585e-01 U_stat=1.470e+02
# naive vs. combo: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:1.000e+00 U_stat=1.120e+02
# infected vs. BNZ: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:1.440e-02 (ns) U_stat=1.720e+02
# naive vs. BNZ: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:1.354e-01 U_stat=1.490e+02
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# naive vs. infected: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:2.808e-01 U_stat=8.600e+01
# infected vs. combo: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:1.466e-01 U_stat=7.700e+01
# combo vs. BNZ: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:4.068e-01 U_stat=1.330e+02
# naive vs. combo: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:3.230e-03 U_stat=4.100e+01
# infected vs. BNZ: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:6.187e-01 U_stat=1.000e+02
# naive vs. BNZ: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:1.440e-02 U_stat=5.300e+01
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# naive vs. infected: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:2.253e-02 (ns) U_stat=1.680e+02
# infected vs. combo: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:1.585e-01 U_stat=7.800e+01
# combo vs. BNZ: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:4.211e-02 (ns) U_stat=1.620e+02
# naive vs. combo: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:8.682e-01 U_stat=1.170e+02
# infected vs. BNZ: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:3.195e-01 U_stat=1.370e+02
# naive vs. BNZ: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:7.016e-03 U_stat=1.780e+02
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# naive vs. infected: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:1.354e-01 U_stat=1.490e+02
# infected vs. combo: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:5.614e-01 U_stat=9.800e+01
# combo vs. BNZ: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:1.012e-02 U_stat=1.750e+02
# naive vs. combo: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:5.338e-01 U_stat=1.280e+02
# infected vs. BNZ: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:3.809e-02 (ns) U_stat=1.630e+02
# naive vs. BNZ: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:7.802e-04 U_stat=1.940e+02
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# naive vs. infected: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:6.783e-01 U_stat=1.230e+02
# infected vs. combo: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:3.615e-01 U_stat=1.350e+02
# combo vs. BNZ: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:1.150e-01 U_stat=1.510e+02
# naive vs. combo: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:4.553e-01 U_stat=1.310e+02
# infected vs. BNZ: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:8.149e-02 U_stat=1.550e+02
# naive vs. BNZ: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:1.354e-01 U_stat=1.490e+02
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# naive vs. infected: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:1.140e-02 (ns) U_stat=1.740e+02
# infected vs. combo: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:1.585e-01 U_stat=7.800e+01
# combo vs. BNZ: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:8.357e-01 U_stat=1.180e+02
# naive vs. combo: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:1.585e-01 U_stat=1.470e+02
# infected vs. BNZ: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:4.553e-01 U_stat=9.400e+01
# naive vs. BNZ: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:8.149e-02 U_stat=1.550e+02
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# naive vs. infected: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:9.669e-01 U_stat=1.140e+02
# infected vs. combo: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:4.306e-01 U_stat=1.320e+02
# combo vs. BNZ: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:1.249e-01 U_stat=1.500e+02
# naive vs. combo: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:4.306e-01 U_stat=1.320e+02
# infected vs. BNZ: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:2.253e-02 (ns) U_stat=1.680e+02
# naive vs. BNZ: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:3.102e-02 (ns) U_stat=1.650e+02
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# naive vs. infected: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:8.357e-01 U_stat=1.070e+02
# infected vs. combo: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:6.482e-01 U_stat=1.010e+02
# combo vs. BNZ: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:8.682e-01 U_stat=1.080e+02
# naive vs. combo: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:1.985e-01 U_stat=8.100e+01
# infected vs. BNZ: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:4.807e-01 U_stat=9.500e+01
# naive vs. BNZ: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:1.466e-01 U_stat=7.700e+01
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# naive vs. infected: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:8.902e-02 U_stat=1.540e+02
# infected vs. combo: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:9.669e-01 U_stat=1.110e+02
# combo vs. BNZ: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:8.357e-01 U_stat=1.180e+02
# naive vs. combo: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:1.150e-01 U_stat=1.510e+02
# infected vs. BNZ: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:9.339e-01 U_stat=1.150e+02
# naive vs. BNZ: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:4.211e-02 (ns) U_stat=1.620e+02
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# naive vs. infected: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:8.972e-03 U_stat=1.760e+02
# infected vs. combo: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:5.338e-01 U_stat=9.700e+01
# combo vs. BNZ: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:9.709e-02 U_stat=1.530e+02
# naive vs. combo: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:9.709e-02 U_stat=1.530e+02
# infected vs. BNZ: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:1.057e-01 U_stat=1.520e+02
# naive vs. BNZ: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:5.760e-04 U_stat=1.960e+02
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# naive vs. infected: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:1.711e-01 U_stat=1.460e+02
# infected vs. combo: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:9.010e-01 U_stat=1.160e+02
# combo vs. BNZ: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:8.035e-01 U_stat=1.190e+02
# naive vs. combo: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:2.998e-01 U_stat=1.380e+02
# infected vs. BNZ: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:4.306e-01 U_stat=1.320e+02
# naive vs. BNZ: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:2.290e-01 U_stat=1.420e+02
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# naive vs. infected: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:9.662e-05 U_stat=2.070e+02
# infected vs. combo: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:2.290e-01 U_stat=8.300e+01
# combo vs. BNZ: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:3.615e-01 U_stat=9.000e+01
# naive vs. combo: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:1.404e-03 U_stat=1.900e+02
# infected vs. BNZ: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:5.124e-02 U_stat=6.500e+01
# naive vs. BNZ: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:9.709e-02 U_stat=1.530e+02
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# naive vs. infected: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:1.711e-01 U_stat=1.460e+02
# infected vs. combo: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:4.807e-01 U_stat=1.300e+02
# combo vs. BNZ: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:5.897e-01 U_stat=9.900e+01
# naive vs. combo: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:6.800e-02 U_stat=1.570e+02
# infected vs. BNZ: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:4.553e-01 U_stat=1.310e+02
# naive vs. BNZ: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:4.649e-02 (ns) U_stat=1.610e+02
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# naive vs. infected: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:2.998e-01 U_stat=1.380e+02
# infected vs. combo: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:6.197e-02 U_stat=1.580e+02
# combo vs. BNZ: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:7.016e-03 U_stat=4.700e+01
# naive vs. combo: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:4.649e-02 (ns) U_stat=1.610e+02
# infected vs. BNZ: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:9.709e-02 U_stat=7.200e+01
# naive vs. BNZ: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:1.000e+00 U_stat=1.130e+02
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# naive vs. infected: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:2.998e-01 U_stat=1.380e+02
# infected vs. combo: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:7.716e-01 U_stat=1.200e+02
# combo vs. BNZ: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:7.400e-01 U_stat=1.040e+02
# naive vs. combo: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:9.709e-02 U_stat=1.530e+02
# infected vs. BNZ: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:8.682e-01 U_stat=1.170e+02
# naive vs. BNZ: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:2.998e-01 U_stat=1.380e+02
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# naive vs. infected: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:2.823e-03 U_stat=1.850e+02
# infected vs. combo: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:6.482e-01 U_stat=1.240e+02
# combo vs. BNZ: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:4.807e-01 U_stat=1.300e+02
# naive vs. combo: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:7.940e-03 U_stat=1.770e+02
# infected vs. BNZ: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:2.628e-01 U_stat=1.400e+02
# naive vs. BNZ: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:1.404e-03 U_stat=1.900e+02
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# naive vs. infected: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:6.185e-01 U_stat=1.250e+02
# infected vs. combo: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:9.835e-01 U_stat=1.135e+02
# combo vs. BNZ: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:8.195e-01 U_stat=1.185e+02
# naive vs. combo: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:6.782e-01 U_stat=1.230e+02
# infected vs. BNZ: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:6.935e-01 U_stat=1.225e+02
# naive vs. BNZ: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:3.193e-01 U_stat=1.370e+02
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# naive vs. infected: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:1.025e-01 U_stat=1.520e+02
# infected vs. combo: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:4.058e-01 U_stat=1.320e+02
# combo vs. BNZ: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:1.228e-01 U_stat=7.600e+01
# naive vs. combo: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:2.798e-02 (ns) U_stat=1.650e+02
# infected vs. BNZ: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:3.980e-01 U_stat=9.200e+01
# naive vs. BNZ: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:5.599e-01 U_stat=1.270e+02
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# naive vs. infected: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:7.716e-01 U_stat=1.200e+02
# infected vs. combo: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:4.807e-01 U_stat=1.300e+02
# combo vs. BNZ: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:9.669e-01 U_stat=1.110e+02
# naive vs. combo: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:2.628e-01 U_stat=1.400e+02
# infected vs. BNZ: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:2.998e-01 U_stat=1.380e+02
# naive vs. BNZ: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:2.134e-01 U_stat=1.430e+02
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# naive vs. infected: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:1.985e-01 U_stat=8.100e+01
# infected vs. combo: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:2.628e-01 U_stat=1.400e+02
# combo vs. BNZ: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:5.069e-01 U_stat=9.600e+01
# naive vs. combo: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:8.035e-01 U_stat=1.190e+02
# infected vs. BNZ: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:5.069e-01 U_stat=1.290e+02
# naive vs. BNZ: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:4.807e-01 U_stat=9.500e+01
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# naive vs. infected: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:3.440e-02 (ns) U_stat=6.100e+01
# infected vs. combo: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:5.069e-01 U_stat=1.290e+02
# combo vs. BNZ: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:3.837e-01 U_stat=1.340e+02
# naive vs. combo: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:2.808e-01 U_stat=8.600e+01
# infected vs. BNZ: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:9.709e-02 U_stat=1.530e+02
# naive vs. BNZ: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:7.089e-01 U_stat=1.030e+02
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# naive vs. infected: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:9.010e-01 U_stat=1.090e+02
# infected vs. combo: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:7.400e-01 U_stat=1.210e+02
# combo vs. BNZ: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:7.089e-01 U_stat=1.030e+02
# naive vs. combo: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:8.682e-01 U_stat=1.080e+02
# infected vs. BNZ: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:8.682e-01 U_stat=1.080e+02
# naive vs. BNZ: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:6.482e-01 U_stat=1.010e+02
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# naive vs. infected: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:2.353e-01 U_stat=8.350e+01
# infected vs. combo: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:1.817e-01 U_stat=1.450e+02
# combo vs. BNZ: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:6.754e-01 U_stat=1.020e+02
# naive vs. combo: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:8.347e-01 U_stat=1.180e+02
# infected vs. BNZ: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:2.425e-01 U_stat=1.410e+02
# naive vs. BNZ: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:1.000e+00 U_stat=1.130e+02
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# naive vs. infected: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:3.489e-01 U_stat=9.200e+01
# infected vs. combo: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:4.916e-01 U_stat=1.280e+02
# combo vs. BNZ: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:3.605e-01 U_stat=1.315e+02
# naive vs. combo: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:5.974e-01 U_stat=1.010e+02
# infected vs. BNZ: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:2.492e-01 U_stat=1.370e+02
# naive vs. BNZ: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:9.185e-01 U_stat=1.150e+02
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# naive vs. infected: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:5.897e-01 U_stat=9.900e+01
# infected vs. combo: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:1.000e+00 U_stat=1.130e+02
# combo vs. BNZ: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:2.808e-01 U_stat=1.390e+02
# naive vs. combo: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:6.482e-01 U_stat=1.010e+02
# infected vs. BNZ: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:1.985e-01 U_stat=1.440e+02
# naive vs. BNZ: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:2.808e-01 U_stat=1.390e+02
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# naive vs. infected: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:5.069e-01 U_stat=9.600e+01
# infected vs. combo: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:4.807e-01 U_stat=1.300e+02
# combo vs. BNZ: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:7.400e-01 U_stat=1.210e+02
# naive vs. combo: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:9.174e-01 U_stat=1.155e+02
# infected vs. BNZ: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:2.290e-01 U_stat=1.420e+02
# naive vs. BNZ: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:5.614e-01 U_stat=1.270e+02
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# naive vs. infected: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:3.195e-01 U_stat=8.800e+01
# infected vs. combo: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:1.000e+00 U_stat=1.130e+02
# combo vs. BNZ: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:2.290e-01 U_stat=1.420e+02
# naive vs. combo: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:4.068e-01 U_stat=9.200e+01
# infected vs. BNZ: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:7.450e-02 U_stat=1.560e+02
# naive vs. BNZ: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:7.089e-01 U_stat=1.220e+02
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# naive vs. infected: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:7.450e-02 U_stat=6.900e+01
# infected vs. combo: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:3.837e-01 U_stat=1.340e+02
# combo vs. BNZ: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:9.504e-01 U_stat=1.145e+02
# naive vs. combo: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:4.553e-01 U_stat=9.400e+01
# infected vs. BNZ: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:3.837e-01 U_stat=1.340e+02
# naive vs. BNZ: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:5.338e-01 U_stat=9.700e+01
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# naive vs. infected: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:3.074e-01 U_stat=8.800e+01
# infected vs. combo: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:4.620e-01 U_stat=1.300e+02
# combo vs. BNZ: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:8.136e-01 U_stat=1.065e+02
# naive vs. combo: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:7.156e-01 U_stat=1.035e+02
# infected vs. BNZ: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:4.962e-01 U_stat=1.290e+02
# naive vs. BNZ: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:3.636e-01 U_stat=9.050e+01
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# naive vs. infected: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:1.160e-01 U_stat=8.250e+01
# infected vs. combo: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:1.520e-01 U_stat=1.410e+02
# combo vs. BNZ: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:3.616e-01 U_stat=1.260e+02
# naive vs. combo: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:7.983e-01 U_stat=1.080e+02
# infected vs. BNZ: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:3.352e-02 (ns) U_stat=1.510e+02
# naive vs. BNZ: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:5.772e-01 U_stat=1.200e+02
