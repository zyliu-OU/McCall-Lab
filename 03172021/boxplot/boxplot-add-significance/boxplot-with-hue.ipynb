# %%
import pandas
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from statannotations.Annotator import Annotator

data_a = pandas.read_csv('03172021-PC-M-F-time-sum-peak.csv')

data_LA = data_a[data_a["organ"].isin(["LA"])]
data_RA = data_a[data_a["organ"].isin(["RA"])]
data_LVT = data_a[data_a["organ"].isin(["LV_top"])]
data_LVB = data_a[data_a["organ"].isin(["LV_bottom"])]
data_RVT = data_a[data_a["organ"].isin(["RV_top"])]
data_RVB = data_a[data_a["organ"].isin(["RV_bottom"])]

mass_list = ['mass_400', 'mass_500', 'mass_600', 'mass_700', 'mass_800']
print(mass_list)

# change the theme of the plot
sns.set_theme(style="white")

plt.rc('xtick',labelsize=16)
plt.rc('ytick',labelsize=16)

order = ['DPI_50', 'DPI_75', 'DPI_142']
hue_order = ['naive', 'infected']
pairs = [(("DPI_50", "naive"), ("DPI_50", "infected")), (("DPI_75", "naive"), ("DPI_75", "infected")), (("DPI_142", "naive"), ("DPI_142", "infected"))]


# if you want the boxplot vertical, make sure change the x and y, and also remove orient='h'.

mass_list_number = 1
for mass in mass_list:
    fig, axes = plt.subplots(2, 3, figsize=(27, 15), constrained_layout=True)
    fig.suptitle(mass)
    g1 = sns.boxplot(ax=axes[0, 0], x=data_LA[str(mass)], y=data_LA['DPI'], hue=data_LA['status'], order = order, palette="tab10", showfliers = False)
    g1 = sns.stripplot(ax=axes[0, 0], x=data_LA[str(mass)], y=data_LA['DPI'], hue=data_LA['status'], order = order, dodge=True, color = "black", size=2, edgecolor="black", linewidth=.9)
    axes[0, 0].set_title("LA", fontsize=16)
    axes[0, 0].set_xlabel('Normalized peak area', fontsize=16)
    #axes[0, 0].set_ylabel('', fontsize=16)
    
    annot_1_hue = Annotator(g1, pairs, x=data_LA[str(mass)], y=data_LA['DPI'], hue=data_LA['status'], order=order, hue_order=hue_order, orient='h')
    annot_1_hue.configure(test='Mann-Whitney', comparisons_correction="BH", correction_format="replace", text_format='star', loc='inside', verbose=2)
    annot_1_hue.apply_test()
    g1, test_results = annot_1_hue.annotate()

    annot_1 = Annotator(g1, [("DPI_50", "DPI_75"), ("DPI_50", "DPI_142"), ("DPI_75", "DPI_142")], x=data_LA[str(mass)], y=data_LA['DPI'], order=order, orient='h')
    annot_1.configure(test='Mann-Whitney', comparisons_correction="BH", correction_format="replace", text_format='star', loc='outside', verbose=2)
    annot_1.apply_test()
    g1, test_results = annot_1.annotate()

    g2 = sns.boxplot(ax=axes[0, 1], x=data_RA[str(mass)], y=data_RA['DPI'], hue=data_RA['status'], order = order, palette="tab10", showfliers = False)
    g2 = sns.stripplot(ax=axes[0, 1], x=data_RA[str(mass)], y=data_RA['DPI'], hue=data_RA['status'], order = order, dodge=True, color = "black", size=2, edgecolor="black", linewidth=.9)
    axes[0, 1].set_title("RA", fontsize=16)
    axes[0, 1].set_xlabel('Normalized peak area', fontsize=16)
    #axes[0, 1].set_ylabel('', fontsize=16)
    
    annot_2_hue = Annotator(g2, pairs, x=data_RA[str(mass)], y=data_RA['DPI'], hue=data_RA['status'], order=order, hue_order=hue_order, orient='h')
    annot_2_hue.configure(test='Mann-Whitney', comparisons_correction="BH", correction_format="replace", text_format='star', loc='inside', verbose=2)
    annot_2_hue.apply_test()
    g2, test_results = annot_2_hue.annotate()

    annot_2 = Annotator(g2, [("DPI_50", "DPI_75"), ("DPI_50", "DPI_142"), ("DPI_75", "DPI_142")], x=data_RA[str(mass)], y=data_RA['DPI'], order=order, orient='h')
    annot_2.configure(test='Mann-Whitney', comparisons_correction="BH", correction_format="replace", text_format='star', loc='outside', verbose=2)
    annot_2.apply_test()
    g2, test_results = annot_2.annotate()
    
    g3 = sns.boxplot(ax=axes[0, 2], x=data_LVT[str(mass)], y=data_LVT['DPI'], hue=data_LVT['status'], order = order, palette="tab10", showfliers = False)
    g3 = sns.stripplot(ax=axes[0, 2], x=data_LVT[str(mass)], y=data_LVT['DPI'], hue=data_LVT['status'], order = order, dodge=True, color = "black", size=2, edgecolor="black", linewidth=.9)
    axes[0, 2].set_title("LVT", fontsize=16)
    axes[0, 2].set_xlabel('Normalized peak area', fontsize=16)
    #axes[0, 2].set_ylabel('', fontsize=16)
    
    annot_3_hue = Annotator(g3, pairs, x=data_LVT[str(mass)], y=data_LVT['DPI'], hue=data_LVT['status'], order=order, hue_order=hue_order, orient='h')
    annot_3_hue.configure(test='Mann-Whitney', comparisons_correction="BH", correction_format="replace", text_format='star', loc='inside', verbose=2)
    annot_3_hue.apply_test()
    g3, test_results = annot_3_hue.annotate()

    annot_3 = Annotator(g3, [("DPI_50", "DPI_75"), ("DPI_50", "DPI_142"), ("DPI_75", "DPI_142")], x=data_LVT[str(mass)], y=data_LVT['DPI'], order=order, orient='h')
    annot_3.configure(test='Mann-Whitney', comparisons_correction="BH", correction_format="replace", text_format='star', loc='outside', verbose=2)
    annot_3.apply_test()
    g3, test_results = annot_3.annotate()
  
    g4 = sns.boxplot(ax=axes[1, 0], x=data_LVB[str(mass)], y=data_LVB['DPI'], hue=data_LVB['status'], order = order, palette="tab10", showfliers = False)
    g4 = sns.stripplot(ax=axes[1, 0], x=data_LVB[str(mass)], y=data_LVB['DPI'], hue=data_LVB['status'], order = order, dodge=True, color = "black", size=2, edgecolor="black", linewidth=.9)
    axes[1, 0].set_title("LVB", fontsize=16)
    axes[1, 0].set_xlabel('Normalized peak area', fontsize=16)
    #axes[1, 0].set_ylabel('', fontsize=16)
    
    annot_4_hue = Annotator(g4, pairs, x=data_LVB[str(mass)], y=data_LVB['DPI'], hue=data_LVB['status'], order=order, hue_order=hue_order, orient='h')
    annot_4_hue.configure(test='Mann-Whitney', comparisons_correction="BH", correction_format="replace", text_format='star', loc='inside', verbose=2)
    annot_4_hue.apply_test()
    g4, test_results = annot_4_hue.annotate()

    annot_4 = Annotator(g4, [("DPI_50", "DPI_75"), ("DPI_50", "DPI_142"), ("DPI_75", "DPI_142")], x=data_LVB[str(mass)], y=data_LVB['DPI'], order=order, orient='h')
    annot_4.configure(test='Mann-Whitney', comparisons_correction="BH", correction_format="replace", text_format='star', loc='outside', verbose=2)
    annot_4.apply_test()
    g4, test_results = annot_4.annotate()
  
    g5 = sns.boxplot(ax=axes[1, 1], x=data_RVT[str(mass)], y=data_RVT['DPI'], hue=data_RVT['status'], order = order, palette="tab10", showfliers = False)
    g5 = sns.stripplot(ax=axes[1, 1], x=data_RVT[str(mass)], y=data_RVT['DPI'], hue=data_RVT['status'], order = order, dodge=True, color = "black", size=2, edgecolor="black", linewidth=.9)
    axes[1, 1].set_title("RVT", fontsize=16)
    axes[1, 1].set_xlabel('Normalized peak area', fontsize=16)
    #axes[1, 1].set_ylabel('', fontsize=16)
    
    annot_5_hue = Annotator(g5, pairs, x=data_RVT[str(mass)], y=data_RVT['DPI'], hue=data_RVT['status'], order=order, hue_order=hue_order, orient='h')
    annot_5_hue.configure(test='Mann-Whitney', comparisons_correction="BH", correction_format="replace", text_format='star', loc='inside', verbose=2)
    annot_5_hue.apply_test()
    g5, test_results = annot_5_hue.annotate()

    annot_5 = Annotator(g5, [("DPI_50", "DPI_75"), ("DPI_50", "DPI_142"), ("DPI_75", "DPI_142")], x=data_RVT[str(mass)], y=data_RVT['DPI'], order=order, orient='h')
    annot_5.configure(test='Mann-Whitney', comparisons_correction="BH", correction_format="replace", text_format='star', loc='outside', verbose=2)
    annot_5.apply_test()
    g5, test_results = annot_5.annotate()
    
    g6 = sns.boxplot(ax=axes[1, 2], x=data_RVB[str(mass)], y=data_RVB['DPI'], hue=data_RVB['status'], order = order, palette="tab10", showfliers = False)
    g6 = sns.stripplot(ax=axes[1, 2], x=data_RVB[str(mass)], y=data_RVB['DPI'], hue=data_RVB['status'], order = order, dodge=True, color = "black", size=2, edgecolor="black", linewidth=.9)
    axes[1, 2].set_title("RVB", fontsize=16)
    axes[1, 2].set_xlabel('Normalized peak area', fontsize=16)
    #axes[1, 2].set_ylabel('', fontsize=16)
    
    annot_6_hue = Annotator(g6, pairs, x=data_RVB[str(mass)], y=data_RVB['DPI'], hue=data_RVB['status'], order=order, hue_order=hue_order, orient='h')
    annot_6_hue.configure(test='Mann-Whitney', comparisons_correction="BH", correction_format="replace", text_format='star', loc='inside', verbose=2)
    annot_6_hue.apply_test()
    g6, test_results = annot_6_hue.annotate()

    annot_6 = Annotator(g6, [("DPI_50", "DPI_75"), ("DPI_50", "DPI_142"), ("DPI_75", "DPI_142")], x=data_RVB[str(mass)], y=data_RVB['DPI'], order=order, orient='h')
    annot_6.configure(test='Mann-Whitney', comparisons_correction="BH", correction_format="replace", text_format='star', loc='outside', verbose=2)
    annot_6.apply_test()
    g6, test_results = annot_6.annotate()
    
    #sns.move_legend(g1, "upper right")
    #sns.move_legend(g2, "upper right")
    #sns.move_legend(g3, "upper right")
    #sns.move_legend(g4, "upper right")
    #sns.move_legend(g5, "upper right")
    #sns.move_legend(g6, "upper right")
    g1.legend([],[], frameon=False)
    g2.legend([],[], frameon=False)
    g3.legend([],[], frameon=False)
    g4.legend([],[], frameon=False)
    g5.legend([],[], frameon=False)
    g6.legend([],[], frameon=False)
    plt.savefig("6-HS-boxplot-time-sum-peaks-" + str(mass) + ".png", dpi=300, bbox_inches='tight')
    mass_list_number += 1
# Out:
# ['mass_400', 'mass_500', 'mass_600', 'mass_700', 'mass_800']
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# DPI_75_naive vs. DPI_75_infected: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:7.016e-03 U_stat=4.700e+01
# DPI_50_naive vs. DPI_50_infected: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:3.401e-01 U_stat=8.900e+01
# DPI_142_naive vs. DPI_142_infected: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:4.553e-01 U_stat=9.400e+01
# C:\Users\zyliu\anaconda3\envs\LAB\lib\site-packages\statannotations\_Plotter.py:337: UserWarning: Invalid x-position found. Are the same parameters passed to seaborn and statannotations calls? or are there few data points?
#   warnings.warn(
# ...
