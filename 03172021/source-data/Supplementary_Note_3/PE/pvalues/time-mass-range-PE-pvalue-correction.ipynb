# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import kendalltau, pearsonr, spearmanr
import statsmodels.api

# all pvalues order is: 50DPI, 75DPI, 142DPI

data_a = pd.read_csv('PE-mass-range-time-6HS-wilcox-FDR-pvalue.csv')
data_a_filename = data_a.filename.to_list()

data_LA = data_a[data_a["organ"].isin(["LA"])]
data_RA = data_a[data_a["organ"].isin(["RA"])]
data_LVT = data_a[data_a["organ"].isin(["LVT"])]
data_LVB = data_a[data_a["organ"].isin(["LVB"])]
data_RVT = data_a[data_a["organ"].isin(["RVT"])]
data_RVB = data_a[data_a["organ"].isin(["RVB"])]

organ_list = ['LA', 'RA', 'LVT', 'LVB', 'RVT', 'RVB']
mass_list = ['mass_400', 'mass_500', 'mass_600', 'mass_700', 'mass_800']

pval_list = []
df_final = pd.DataFrame(data_a_filename, columns = ['filename'])

for mass in mass_list:
    for organ in organ_list:
        data_organ = data_a[data_a["organ"].isin([organ])]
        organ_pval_list = data_organ[mass].tolist()
        organ_pval_list_corrected = statsmodels.stats.multitest.fdrcorrection(organ_pval_list, method='indep')
        pval_list.extend(organ_pval_list_corrected[1])
        print(organ_pval_list)
        print(organ_pval_list_corrected[1])
    df_final[mass] = pval_list
    print(pval_list)
    pval_list = []
    
df_final.to_csv('PE-mass-range-time-6HS-comparison-FDR-pvalue.csv', index=False)
# Out:
# [0.835687009, 0.008326074, 0.50765136]
# [0.83568701 0.02497822 0.76147704]
# [0.365570111, 0.200856841, 0.315368503]
# [0.36557011 0.36557011 0.36557011]
# [0.148657955, 0.708799549, 0.117480733]
# [0.22298693 0.70879955 0.22298693]
# [0.0925494, 0.011532289, 0.024687057]
# [0.0925494  0.03459687 0.03703059]
# [0.117480733, 0.005766144, 0.743702065]
# [0.1762211  0.01729843 0.74370207]
# [0.742808798, 0.067496154, 0.07533356]
# [0.7428088  0.11300034 0.11300034]
# [0.835687009, 0.024978221999999998, 0.76147704, 0.365570111, 0.365570111, 0.365570111, 0.2229869325, 0.708799549, 0.2229869325, 0.0925494, 0.034596867, 0.0370305855, 0.1762210995, 0.017298432000000002, 0.743702065, 0.742808798, 0.11300033999999999, 0.11300033999999999]
# [0.835687009, 0.64060794, 0.891206406]
# [0.89120641 0.89120641 0.89120641]
# [0.365570111, 0.027386204, 0.315368503]
# [0.36557011 0.08215861 0.36557011]
# [0.148657955, 0.708799549, 0.717245066]
# [0.44597387 0.71724507 0.71724507]
# [0.036297931, 0.038497825, 0.103234334]
# [0.05774674 0.05774674 0.10323433]
# [0.2438144, 0.005766144, 0.10213207]
# [0.2438144  0.01729843 0.15319811]
# [0.742808798, 3.27e-05, 0.062706921]
# [7.42808798e-01 9.81000000e-05 9.40603815e-02]
# [0.891206406, 0.891206406, 0.891206406, 0.365570111, 0.082158612, 0.365570111, 0.445973865, 0.717245066, 0.717245066, 0.0577467375, 0.0577467375, 0.103234334, 0.2438144, 0.017298432000000002, 0.15319810500000003, 0.742808798, 9.810000000000001e-05, 0.0940603815]
# [0.006984939, 0.64060794, 0.257564854]
# [0.02095482 0.64060794 0.38634728]
# [0.365570111, 0.007614766, 0.359594433]
# [0.36557011 0.0228443  0.36557011]
# [0.123899975, 0.708799549, 0.787439197]
# [0.37169992 0.7874392  0.7874392 ]
# [0.036297931, 0.06941205, 0.003349876]
# [0.0544469  0.06941205 0.01004963]
# [0.271332211, 0.007121117, 0.09603581]
# [0.27133221 0.02136335 0.14405371]
# [0.742808798, 0.001522829, nan]
# [nan nan nan]
# [0.020954817, 0.64060794, 0.38634728100000004, 0.365570111, 0.022844298000000002, 0.365570111, 0.371699925, 0.787439197, 0.787439197, 0.0544468965, 0.06941205, 0.010049628, 0.271332211, 0.021363351, 0.144053715, nan, nan, nan]
# [0.034837178, 0.682673808, 1.0]
# [0.10451153 1.         1.        ]
# [0.88444639, 0.008125834, 0.678167267]
# [0.88444639 0.0243775  0.88444639]
# [0.847835852, 0.708799549, 0.352123554]
# [0.84783585 0.84783585 0.84783585]
# [0.121458709, 0.201577564, 0.708613726]
# [0.30236635 0.30236635 0.70861373]
# [0.759406454, 0.007121117, 0.09603581]
# [0.75940645 0.02136335 0.14405371]
# [0.742808798, 0.020379206, 0.523998656]
# [0.7428088  0.06113762 0.7428088 ]
# [0.10451153400000002, 1.0, 1.0, 0.88444639, 0.024377502000000002, 0.88444639, 0.847835852, 0.847835852, 0.847835852, 0.302366346, 0.302366346, 0.708613726, 0.759406454, 0.021363351, 0.144053715, 0.742808798, 0.061137618000000005, 0.742808798]
# [0.012122966, 0.4337665, 0.50765136]
# [0.0363689  0.50765136 0.50765136]
# [0.365570111, 0.523998656, 0.678167267]
# [0.67816727 0.67816727 0.67816727]
# [0.946975393, 0.708799549, 0.717245066]
# [0.94697539 0.94697539 0.94697539]
# [0.124455237, 0.038497825, 0.708613726]
# [0.18668286 0.11549347 0.70861373]
# [0.759406454, 0.01054179, 0.205492778]
# [0.75940645 0.03162537 0.30823917]
# [0.742808798, 0.022620767, nan]
# [nan nan nan]
# [0.036368898000000004, 0.50765136, 0.50765136, 0.678167267, 0.678167267, 0.678167267, 0.946975393, 0.946975393, 0.946975393, 0.1866828555, 0.115493475, 0.708613726, 0.759406454, 0.03162537000000001, 0.308239167, nan, nan, nan]

# %%
mass_600_RVB = [0.742808798, 0.001522829]
mass_600_RVB_corrected = statsmodels.stats.multitest.fdrcorrection(mass_600_RVB, method='indep')
print(mass_600_RVB_corrected[1])
# Out:
# [0.7428088  0.00304566]

# %%
mass_800_RVB = [0.742808798, 0.022620767]
mass_800_RVB_corrected = statsmodels.stats.multitest.fdrcorrection(mass_800_RVB, method='indep')
print(mass_800_RVB_corrected[1])
# Out:
# [0.7428088  0.04524153]
