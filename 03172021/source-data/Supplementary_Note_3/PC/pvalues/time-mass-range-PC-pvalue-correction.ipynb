# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import kendalltau, pearsonr, spearmanr
import statsmodels.api

# all pvalues order is: 50DPI, 75DPI, 142DPI

data_a = pd.read_csv('PC-mass-range-time-6HS-wilcox-FDR-pvalue.csv')
data_a_filename = data_a.filename.to_list()

data_LA = data_a[data_a["organ"].isin(["LA"])]
data_RA = data_a[data_a["organ"].isin(["RA"])]
data_LVT = data_a[data_a["organ"].isin(["LVT"])]
data_LVB = data_a[data_a["organ"].isin(["LVB"])]
data_RVT = data_a[data_a["organ"].isin(["RVT"])]
data_RVB = data_a[data_a["organ"].isin(["RVB"])]

organ_list = ['LA', 'RA', 'LVT', 'LVB', 'RVT', 'RVB']
mass_list = ['mass_400', 'mass_500', 'mass_600', 'mass_700', 'mass_800']

pval_list = []
df_final = pd.DataFrame(data_a_filename, columns = ['filename'])

for mass in mass_list:
    for organ in organ_list:
        data_organ = data_a[data_a["organ"].isin([organ])]
        organ_pval_list = data_organ[mass].tolist()
        organ_pval_list_corrected = statsmodels.stats.multitest.fdrcorrection(organ_pval_list, method='indep')
        pval_list.extend(organ_pval_list_corrected[1])
        print(organ_pval_list)
        print(organ_pval_list_corrected[1])
    df_final[mass] = pval_list
    print(pval_list)
    pval_list = []
    
df_final.to_csv('PC-mass-range-time-6HS-comparison-FDR-pvalue.csv', index=False)
# Out:
# [0.345310897, 0.028517539, 0.967417298]
# [0.51796635 0.08555262 0.9674173 ]
# [0.342435561, 0.018760013, 0.50765136]
# [0.50765136 0.05628004 0.50765136]
# [0.445161707, 0.648722165, 0.082359104]
# [0.64872217 0.64872217 0.24707731]
# [0.486364764, 0.009185777, 0.171217781]
# [0.48636476 0.02755733 0.25682667]
# [0.65287003, 0.00070179, 0.682673808]
# [0.68267381 0.00210537 0.68267381]
# [0.774840302, 2.4e-05, 0.024687057]
# [7.74840302e-01 7.20000000e-05 3.70305855e-02]
# [0.5179663455000001, 0.08555261700000001, 0.967417298, 0.50765136, 0.056280039, 0.50765136, 0.648722165, 0.648722165, 0.24707731200000002, 0.486364764, 0.027557330999999997, 0.25682667150000005, 0.682673808, 0.00210537, 0.682673808, 0.774840302, 7.2e-05, 0.0370305855]
# [0.271070798, 0.475734785, 0.967417298]
# [0.71360218 0.71360218 0.9674173 ]
# [0.342435561, 0.018760013, 0.838134777]
# [0.51365334 0.05628004 0.83813478]
# [0.056280039, 0.929627582, 0.148657955]
# [0.16884012 0.92962758 0.22298693]
# [0.222986933, 0.008326074, 0.018858863]
# [0.22298693 0.02497822 0.02828829]
# [0.405685219, 0.004503123, 0.512274875]
# [0.51227488 0.01350937 0.51227488]
# [0.774840302, 0.004163037, 0.000102052]
# [7.74840302e-01 6.24455550e-03 3.06156000e-04]
