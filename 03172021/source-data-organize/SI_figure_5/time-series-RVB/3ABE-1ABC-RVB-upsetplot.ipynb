# %%
import pandas
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns; sns.set_theme(color_codes=True)
from matplotlib.pyplot import gcf
from upsetplot import UpSet
from matplotlib import cm

col_colors = pandas.read_csv("3ABE-1ABC-RVB-feature-table-trans.csv")
col_colors = col_colors.set_index('DPI')
col_colors[col_colors != 0] = 1
col_colors[col_colors == 0] = ""

col_colors = col_colors.set_index(col_colors.DPI_50 == 1).set_index(col_colors.DPI_75 == 1, append=True).set_index(col_colors.DPI_142 == 1, append=True)

upset = UpSet(col_colors,show_counts = True, sort_categories_by = None, sort_by='cardinality', min_subset_size=100)  # disable the default bar chart
plt.figure(figsize = (40, 20))
plt.style.use('default')
upset.plot()
plt.legend(frameon=False)
plt.suptitle("RVB")
plt.savefig("upset-plot-3ABE-1ABC-RVB.pdf", dpi = 300, bbox_inches = 'tight')
plt.savefig("upset-plot-3ABE-1ABC-RVB.png", dpi = 300, bbox_inches = 'tight')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
